# %% [markdown]
# # SVM using SGD

# %% [markdown]
# ## First look at datasets

# %%
## Dataset tiny
import matplotlib.pyplot as plt 
from DataLoader import *
from LinearSVM import *
dataloader = DataLoader()

# Tiny 
xtrain, xtest, ytrain, ytest = dataloader.get_toydata_tiny()

# Entire dataset
X = np.concatenate((xtrain, xtest))
Y = np.concatenate((ytrain, ytest))
plt.title("Tiny Data-Set", fontweight="bold", fontsize=12)
plt.scatter(X[Y==-1,0], X[Y==-1,1], label='Class -1', alpha=0.7)
plt.scatter(X[Y==1,0], X[Y==1,1], label='Class 1', alpha=0.7)
plt.xlabel("x1"); plt.ylabel("x2")
plt.legend()
plt.show()

counts = dict()
for x in np.unique(Y).astype(int):
    counts[x] = np.count_nonzero(Y == x)

print("Tiny-Set:")
plt.pie(x=counts.values(), labels=counts.keys(), autopct='%1.1f%%')
plt.show() # roughly balanced data set

# Large 
xtrain, xtest, ytrain, ytest = dataloader.get_toydata_large()
Y = np.concatenate((ytrain, ytest))

counts = dict()
for x in np.unique(Y).astype(int):
    counts[x] = np.count_nonzero(Y == x)

print("Large-Set:")
plt.pie(x=counts.values(), labels=counts.keys(), autopct='%1.1f%%')
plt.show() # roughly balanced data set

# MNIST
xtrain, xtest, ytrain, ytest = dataloader.get_mnist()
Y = np.concatenate((ytrain, ytest))

counts = dict()
for x in np.unique(Y).astype(int):
    counts[x] = np.count_nonzero(Y == x)

print("MNIST:")
plt.pie(x=counts.values(), labels=counts.keys(), autopct='%1.1f%%')
plt.show() # roughly balanced data set
# Out:
# Tiny-Set:
# Large-Set:
# MNIST:

# %% [markdown]
# ## Hyperparameter Search -- Tiny

# %%
import matplotlib.pyplot as plt 
from DataLoader import *
from LinearSVM import *
from pprint import pprint
from DataUtils import *

dataloader = DataLoader()
xtrain, xtest, ytrain, ytest = dataloader.get_toydata_tiny()

lrs = [0.1, 0.5, 1, 3, 5]; Cs = [0.001, 0.01, 0.1, 0.5]
batch_sizes = [10, 20, 30, 40]

results = {}
for lr in tqdm(lrs):
    for C in Cs:
        for batch in batch_sizes:
            svm = LinearSVM(learning_rate=lr, regularization=C, batch_size=batch)
            results[f'lr:{lr}, C:{C}, batch:{batch}'] = DataUtils.cross_validation_score(svm, xtrain, ytrain, k=5)
results = sorted(results.items(), key=lambda l:l[1], reverse=True)

print("\n\n Best parameters and their resulting classification accuracy:")
pprint(results[:5])
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]Finished in 0:00:00.034905
# Finished in 0:00:00.029919
# Finished in 0:00:00.027949
# Finished in 0:00:00.026905
# Finished in 0:00:00.024933
# Finished in 0:00:00.024934
# Finished in 0:00:00.024932
# Finished in 0:00:00.023936
# Finished in 0:00:00.032912
# Finished in 0:00:00.027922
# Finished in 0:00:00.025931
# Finished in 0:00:00.024933
# Finished in 0:00:00.024933
# Finished in 0:00:00.024933
# Finished in 0:00:00.023936
# Finished in 0:00:00.022939
# Finished in 0:00:00.023936
# Finished in 0:00:00.026928
# Finished in 0:00:00.025931
# Finished in 0:00:00.022939
# Finished in 0:00:00.025930
# Finished in 0:00:00.024934
# Finished in 0:00:00.027925
# Finished in 0:00:00.026929
# Finished in 0:00:00.024932
# Finished in 0:00:00.027926
# Finished in 0:00:00.027926
# Finished in 0:00:00.028922
# Finished in 0:00:00.028923
# Finished in 0:00:00.027926
# Finished in 0:00:00.025930
# Finished in 0:00:00.027926
# Finished in 0:00:00.026929
# Finished in 0:00:00.027925
# Finished in 0:00:00.026928
# Finished in 0:00:00.024933
# Finished in 0:00:00.023935
# Finished in 0:00:00.027927
# Finished in 0:00:00.026927
# Finished in 0:00:00.025930
# Finished in 0:00:00.025930
# Finished in 0:00:00.031915
# Finished in 0:00:00.030917
# Finished in 0:00:00.029921
# Finished in 0:00:00.027925
# Finished in 0:00:00.026927
# Finished in 0:00:00.025931
# Finished in 0:00:00.025932
# Finished in 0:00:00.025954
# Finished in 0:00:00.028920
# Finished in 0:00:00.025930
# Finished in 0:00:00.024955
# Finished in 0:00:00.024933
# Finished in 0:00:00.025931
# Finished in 0:00:00.025910
# Finished in 0:00:00.023935
# Finished in 0:00:00.022939
# Finished in 0:00:00.024954
# Finished in 0:00:00.026906
# Finished in 0:00:00.025927
# Finished in 0:00:00.032933
# Finished in 0:00:00.032912
# Finished in 0:00:00.033889
# Finished in 0:00:00.035863
# Finished in 0:00:00.031914
# Finished in 0:00:00.032913
# Finished in 0:00:00.028922
# Finished in 0:00:00.027926
# Finished in 0:00:00.029920
# Finished in 0:00:00.025930
# Finished in 0:00:00.026927
# Finished in 0:00:00.026929
# Finished in 0:00:00.025922
#  20%|██        | 1/5 [00:02<00:08,  2.21s/it]Finished in 0:00:00.031915
# Finished in 0:00:00.027925
# Finished in 0:00:00.026928
# Finished in 0:00:00.024933
# Finished in 0:00:00.024933
# Finished in 0:00:00.024933
# Finished in 0:00:00.025952
# Finished in 0:00:00.024954
# Finished in 0:00:00.025909
# Finished in 0:00:00.026927
# Finished in 0:00:00.022940
# Finished in 0:00:00.019945
# Finished in 0:00:00.018949
# Finished in 0:00:00.018950
# Finished in 0:00:00.018950
# Finished in 0:00:00.019948
# Finished in 0:00:00.019948
# Finished in 0:00:00.018946
# Finished in 0:00:00.018950
# Finished in 0:00:00.017951
# Finished in 0:00:00.021942
# Finished in 0:00:00.018950
# Finished in 0:00:00.015956
# Finished in 0:00:00.017953
# Finished in 0:00:00.019945
# Finished in 0:00:00.016954
# Finished in 0:00:00.016955
# Finished in 0:00:00.020965
# Finished in 0:00:00.021902
# Finished in 0:00:00.023957
# Finished in 0:00:00.021941
# Finished in 0:00:00.022918
# Finished in 0:00:00.019968
# Finished in 0:00:00.019946
# Finished in 0:00:00.019946
# Finished in 0:00:00.019947
# Finished in 0:00:00.018971
# Finished in 0:00:00.018949
# Finished in 0:00:00.020922
# Finished in 0:00:00.017952
# Finished in 0:00:00.019958
# Finished in 0:00:00.025919
# Finished in 0:00:00.017952
# Finished in 0:00:00.017952
# Finished in 0:00:00.015957
# Finished in 0:00:00.017952
# Finished in 0:00:00.016955
# Finished in 0:00:00.021941
# Finished in 0:00:00.024934
# Finished in 0:00:00.023936
# Finished in 0:00:00.021941
# Finished in 0:00:00.026929
# Finished in 0:00:00.020942
# Finished in 0:00:00.021941
# Finished in 0:00:00.022938
# Finished in 0:00:00.022939
# Finished in 0:00:00.020943
# Finished in 0:00:00.019947
# Finished in 0:00:00.019947
# Finished in 0:00:00.019946
# Finished in 0:00:00.019946
# Finished in 0:00:00.021942
# Finished in 0:00:00.017956
# Finished in 0:00:00.017946
# Finished in 0:00:00.018949
# Finished in 0:00:00.017952
# Finished in 0:00:00.016954
# Finished in 0:00:00.029919
# Finished in 0:00:00.031937
# Finished in 0:00:00.030938
# Finished in 0:00:00.035904
# Finished in 0:00:00.031893
# Finished in 0:00:00.026950
# Finished in 0:00:00.027925
# Finished in 0:00:00.027923
# Finished in 0:00:00.027926
# Finished in 0:00:00.025930
# Finished in 0:00:00.024934
# Finished in 0:00:00.026928
# Finished in 0:00:00.024932
# Finished in 0:00:00.023936
# Finished in 0:00:00.023958
# Finished in 0:00:00.021942
# Finished in 0:00:00.022918
# Finished in 0:00:00.023935
# Finished in 0:00:00.022938
#  40%|████      | 2/5 [00:03<00:05,  1.96s/it]Finished in 0:00:00.022940
# Finished in 0:00:00.024892
# Finished in 0:00:00.019947
# Finished in 0:00:00.018948
# Finished in 0:00:00.019947
# Finished in 0:00:00.018950
# Finished in 0:00:00.017951
# Finished in 0:00:00.017976
# Finished in 0:00:00.019938
# Finished in 0:00:00.017938
# Finished in 0:00:00.024933
# Finished in 0:00:00.017951
# Finished in 0:00:00.019947
# Finished in 0:00:00.018949
# Finished in 0:00:00.016956
# Finished in 0:00:00.016954
# Finished in 0:00:00.017951
# Finished in 0:00:00.018952
# Finished in 0:00:00.020944
# Finished in 0:00:00.016955
# Finished in 0:00:00.023937
# Finished in 0:00:00.036901
# Finished in 0:00:00.024935
# Finished in 0:00:00.026927
# Finished in 0:00:00.026928
# Finished in 0:00:00.019946
# Finished in 0:00:00.019947
# Finished in 0:00:00.019947
# Finished in 0:00:00.018950
# Finished in 0:00:00.025930
# Finished in 0:00:00.019946
# Finished in 0:00:00.016955
# Finished in 0:00:00.015957
# Finished in 0:00:00.016955
# Finished in 0:00:00.016954
# Finished in 0:00:00.015958
# Finished in 0:00:00.014959
# Finished in 0:00:00.020945
# Finished in 0:00:00.016955
# Finished in 0:00:00.016954
# Finished in 0:00:00.016955
# Finished in 0:00:00.026929
# Finished in 0:00:00.024933
# Finished in 0:00:00.023936
# Finished in 0:00:00.024933
# Finished in 0:00:00.021941
# Finished in 0:00:00.020944
# Finished in 0:00:00.019948
# Finished in 0:00:00.019946
# Finished in 0:00:00.018949
# Finished in 0:00:00.020943
# Finished in 0:00:00.016954
# Finished in 0:00:00.017953
# Finished in 0:00:00.018948
# Finished in 0:00:00.018950
# Finished in 0:00:00.016955
# Finished in 0:00:00.017952
# Finished in 0:00:00.017951
# Finished in 0:00:00.017952
# Finished in 0:00:00.017951
# Finished in 0:00:00.015958
# Finished in 0:00:00.033909
# Finished in 0:00:00.031915
# Finished in 0:00:00.030918
# Finished in 0:00:00.030917
# Finished in 0:00:00.029920
# Finished in 0:00:00.026928
# Finished in 0:00:00.026949
# Finished in 0:00:00.031893
# Finished in 0:00:00.029941
# Finished in 0:00:00.027881
# Finished in 0:00:00.023957
# Finished in 0:00:00.025911
# Finished in 0:00:00.025951
# Finished in 0:00:00.024933
# Finished in 0:00:00.022917
# Finished in 0:00:00.020944
#  60%|██████    | 3/5 [00:05<00:03,  1.88s/it]Finished in 0:00:00.026928
# Finished in 0:00:00.022939
# Finished in 0:00:00.023935
# Finished in 0:00:00.022939
# Finished in 0:00:00.020943
# Finished in 0:00:00.019945
# Finished in 0:00:00.019968
# Finished in 0:00:00.019925
# Finished in 0:00:00.018949
# Finished in 0:00:00.015979
# Finished in 0:00:00.018949
# Finished in 0:00:00.017955
# Finished in 0:00:00.017948
# Finished in 0:00:00.016955
# Finished in 0:00:00.014960
# Finished in 0:00:00.015958
# Finished in 0:00:00.014960
# Finished in 0:00:00.013961
# Finished in 0:00:00.014960
# Finished in 0:00:00.013963
# Finished in 0:00:00.013963
# Finished in 0:00:00.014960
# Finished in 0:00:00.015957
# Finished in 0:00:00.018950
# Finished in 0:00:00.019946
# Finished in 0:00:00.019947
# Finished in 0:00:00.018950
# Finished in 0:00:00.018949
# Finished in 0:00:00.018949
# Finished in 0:00:00.017952
# Finished in 0:00:00.016954
# Finished in 0:00:00.017952
# Finished in 0:00:00.016955
# Finished in 0:00:00.016954
# Finished in 0:00:00.017952
# Finished in 0:00:00.014960
# Finished in 0:00:00.016956
# Finished in 0:00:00.014960
# Finished in 0:00:00.014961
# Finished in 0:00:00.013962
# Finished in 0:00:00.013963
# Finished in 0:00:00.013962
# Finished in 0:00:00.012967
# Finished in 0:00:00.013962
# Finished in 0:00:00.019947
# Finished in 0:00:00.019946
# Finished in 0:00:00.022939
# Finished in 0:00:00.019948
# Finished in 0:00:00.020943
# Finished in 0:00:00.017952
# Finished in 0:00:00.017973
# Finished in 0:00:00.016955
# Finished in 0:00:00.018927
# Finished in 0:00:00.017952
# Finished in 0:00:00.015978
# Finished in 0:00:00.014938
# Finished in 0:00:00.016950
# Finished in 0:00:00.017951
# Finished in 0:00:00.014960
# Finished in 0:00:00.013963
# Finished in 0:00:00.013963
# Finished in 0:00:00.014960
# Finished in 0:00:00.012965
# Finished in 0:00:00.015958
# Finished in 0:00:00.028922
# Finished in 0:00:00.030917
# Finished in 0:00:00.029941
# Finished in 0:00:00.034886
# Finished in 0:00:00.030917
# Finished in 0:00:00.027946
# Finished in 0:00:00.027905
# Finished in 0:00:00.026949
# Finished in 0:00:00.028906
# Finished in 0:00:00.026924
# Finished in 0:00:00.022938
#  80%|████████  | 4/5 [00:07<00:01,  1.76s/it]Finished in 0:00:00.027926
# Finished in 0:00:00.023956
# Finished in 0:00:00.025909
# Finished in 0:00:00.023936
# Finished in 0:00:00.036902
# Finished in 0:00:00.022939
# Finished in 0:00:00.021940
# Finished in 0:00:00.021942
# Finished in 0:00:00.020944
# Finished in 0:00:00.023936
# Finished in 0:00:00.019947
# Finished in 0:00:00.018949
# Finished in 0:00:00.020944
# Finished in 0:00:00.018950
# Finished in 0:00:00.015957
# Finished in 0:00:00.015958
# Finished in 0:00:00.016954
# Finished in 0:00:00.017952
# Finished in 0:00:00.015957
# Finished in 0:00:00.016955
# Finished in 0:00:00.016954
# Finished in 0:00:00.015957
# Finished in 0:00:00.015958
# Finished in 0:00:00.014960
# Finished in 0:00:00.013963
# Finished in 0:00:00.014961
# Finished in 0:00:00.016955
# Finished in 0:00:00.012987
# Finished in 0:00:00.013963
# Finished in 0:00:00.018926
# Finished in 0:00:00.018951
# Finished in 0:00:00.019967
# Finished in 0:00:00.023936
# Finished in 0:00:00.018949
# Finished in 0:00:00.015958
# Finished in 0:00:00.015978
# Finished in 0:00:00.016932
# Finished in 0:00:00.015958
# Finished in 0:00:00.015979
# Finished in 0:00:00.013962
# Finished in 0:00:00.014981
# Finished in 0:00:00.014938
# Finished in 0:00:00.015979
# Finished in 0:00:00.014939
# Finished in 0:00:00.015980
# Finished in 0:00:00.013984
# Finished in 0:00:00.013962
# Finished in 0:00:00.013943
# Finished in 0:00:00.012964
# Finished in 0:00:00.019947
# Finished in 0:00:00.020965
# Finished in 0:00:00.020922
# Finished in 0:00:00.019969
# Finished in 0:00:00.018949
# Finished in 0:00:00.016933
# Finished in 0:00:00.017952
# Finished in 0:00:00.020944
# Finished in 0:00:00.020944
# Finished in 0:00:00.015958
# Finished in 0:00:00.019946
# Finished in 0:00:00.014959
# Finished in 0:00:00.015957
# Finished in 0:00:00.015958
# Finished in 0:00:00.014960
# Finished in 0:00:00.013963
# Finished in 0:00:00.012966
# Finished in 0:00:00.011967
# Finished in 0:00:00.012967
# Finished in 0:00:00.012963
# Finished in 0:00:00.033911
# Finished in 0:00:00.031913
# Finished in 0:00:00.030940
# Finished in 0:00:00.030895
# Finished in 0:00:00.028944
# Finished in 0:00:00.026906
# Finished in 0:00:00.026928
# Finished in 0:00:00.032912
# Finished in 0:00:00.027926
# Finished in 0:00:00.025931
# Finished in 0:00:00.023935
# Finished in 0:00:00.023937
# Finished in 0:00:00.023935
# Finished in 0:00:00.024934
# Finished in 0:00:00.024955
# Finished in 0:00:00.020925
# 100%|██████████| 5/5 [00:08<00:00,  1.79s/it]Finished in 0:00:00.026925
# Finished in 0:00:00.023937
# Finished in 0:00:00.022938
# Finished in 0:00:00.022938
#
#
#  Best parameters and their resulting classification accuracy:
# [('lr:1, C:0.001, batch:10', 1.0),
#  ('lr:0.1, C:0.001, batch:10', 0.9928571428571429),
#  ('lr:0.1, C:0.01, batch:10', 0.9928571428571429),
#  ('lr:0.1, C:0.1, batch:10', 0.9928571428571429),
#  ('lr:0.5, C:0.001, batch:10', 0.9928571428571429)]

# %% [markdown]
# ## Classification accuracy and convergence plot

# %%
from DataLoader import *
from LinearSVM import *

dataloader = DataLoader()
xtrain, xtest, ytrain, ytest = dataloader.get_toydata_tiny()

# best hyperparameters
lr = 1; C = 0.001; batch_size=10
svm = LinearSVM(learning_rate=lr, regularization=C, batch_size=batch_size, show_plot=True, collect_data=True)
svm.fit(xtrain, ytrain)

# Convergence Plots
plt.subplot(1,2,1)
plt.title("Hinge Loss", fontweight="bold", fontsize=11)
plt.plot(svm.losses, lw=3, alpha=0.6)
plt.xlabel("Epoch", fontweight="bold"); plt.ylabel("Loss", fontweight="bold")

plt.subplot(1,2,2)
plt.title("Classification Accuracy", fontweight="bold", fontsize=11)
plt.plot(svm.accuracies * 100, lw=2, alpha=0.8)
plt.xlabel("Epoch", fontweight="bold"); plt.ylabel("Accuracy %", fontweight="bold")
plt.tight_layout()
plt.show()

print("\nMargins and decision boudary for test set: ")
svm.plot_margin(xtest, ytest)

# classification accuracy
print("\nClassification accuracy evaluated on test set with computed weights:", end=" ")
print(round(svm.accuracy(xtest, ytest, svm.optimizer.weight), 2)*100, "%\n")
# Out:
# Finished in 0:00:00.029941
#
# Computed margins and decision boudary for training set:
# Margins and decision boudary for test set:
# Classification accuracy evaluated on test set with computed weights: 100.0 %

# %% [markdown]
# ## Hyperparameter Search -- Large

# %%
import matplotlib.pyplot as plt 
from DataLoader import *
from LinearSVM import *
from pprint import pprint
from DataUtils import *

dataloader = DataLoader()
xtrain, xtest, ytrain, ytest = dataloader.get_toydata_large()

lrs = [0.1, 0.5, 1, 3]; Cs = [0.001, 0.01, 0.1]
batch_sizes = [50, 100, 200]
results = {}

for lr in tqdm(lrs):
    for C in Cs:
        for batch in batch_sizes:
            svm = LinearSVM(learning_rate=lr, regularization=C, batch_size=batch, epoch_count=3)
            results[f'lr:{lr}, C:{C}, batch:{batch}'] = DataUtils.cross_validation_score(svm, xtrain, ytrain, k=5)
results = sorted(results.items(), key=lambda l:l[1], reverse=True)

print("\n\n Best parameters and their resulting classification accuracy:")
pprint(results[:5])
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]Finished in 0:00:01.927843
# Finished in 0:00:01.956766
# Finished in 0:00:01.724389
# Finished in 0:00:02.009625
# Finished in 0:00:01.773258
# Finished in 0:00:01.698456
# Finished in 0:00:01.763283
# Finished in 0:00:02.034557
# Finished in 0:00:01.854019
# Finished in 0:00:01.715411
# Finished in 0:00:01.700451
# Finished in 0:00:01.821107
# Finished in 0:00:01.773267
# Finished in 0:00:01.701449
# Finished in 0:00:01.761288
# Finished in 0:00:01.732366
# Finished in 0:00:01.750318
# Finished in 0:00:01.766276
# Finished in 0:00:01.765277
# Finished in 0:00:01.771263
# Finished in 0:00:01.782253
# Finished in 0:00:01.755304
# Finished in 0:00:01.867007
# Finished in 0:00:01.947810
# Finished in 0:00:01.825116
# Finished in 0:00:02.044510
# Finished in 0:00:01.730351
# Finished in 0:00:01.726383
# Finished in 0:00:01.784228
# Finished in 0:00:01.709406
# Finished in 0:00:01.709426
# Finished in 0:00:01.760298
# Finished in 0:00:01.739347
# Finished in 0:00:01.749319
# Finished in 0:00:01.871992
# Finished in 0:00:01.769268
# Finished in 0:00:01.798190
# Finished in 0:00:01.821105
# Finished in 0:00:01.785226
# Finished in 0:00:01.803156
# Finished in 0:00:01.694468
# Finished in 0:00:01.694489
# Finished in 0:00:01.763261
# Finished in 0:00:01.737353
#  25%|██▌       | 1/4 [01:21<04:04, 81.51s/it]Finished in 0:00:01.728357
# Finished in 0:00:01.820128
# Finished in 0:00:01.735358
# Finished in 0:00:01.769266
# Finished in 0:00:01.749300
# Finished in 0:00:01.898920
# Finished in 0:00:01.903908
# Finished in 0:00:02.130754
# Finished in 0:00:03.017995
# Finished in 0:00:01.921859
# Finished in 0:00:01.742340
# Finished in 0:00:02.035533
# Finished in 0:00:01.796195
# Finished in 0:00:01.729374
# Finished in 0:00:01.755317
# Finished in 0:00:01.686467
# Finished in 0:00:01.787220
# Finished in 0:00:01.763283
# Finished in 0:00:01.864014
# Finished in 0:00:01.827114
# Finished in 0:00:01.802181
# Finished in 0:00:01.720396
# Finished in 0:00:01.736335
# Finished in 0:00:01.679507
# Finished in 0:00:01.668517
# Finished in 0:00:01.776228
# Finished in 0:00:01.795178
# Finished in 0:00:01.748323
# Finished in 0:00:01.699453
# Finished in 0:00:01.702447
# Finished in 0:00:01.728377
# Finished in 0:00:01.714414
# Finished in 0:00:01.718383
# Finished in 0:00:01.726381
# Finished in 0:00:01.709436
# Finished in 0:00:01.699434
# Finished in 0:00:01.703422
# Finished in 0:00:01.704418
# Finished in 0:00:01.675498
# Finished in 0:00:01.724367
# Finished in 0:00:01.694468
# Finished in 0:00:01.667518
# Finished in 0:00:01.741342
# Finished in 0:00:01.707412
# Finished in 0:00:01.872989
#  50%|█████     | 2/4 [02:43<02:43, 81.63s/it]Finished in 0:00:01.806147
# Finished in 0:00:01.746347
# Finished in 0:00:01.700451
# Finished in 0:00:01.807167
# Finished in 0:00:01.742339
# Finished in 0:00:01.774256
# Finished in 0:00:01.746352
# Finished in 0:00:01.669535
# Finished in 0:00:01.716409
# Finished in 0:00:01.689482
# Finished in 0:00:01.714393
# Finished in 0:00:01.718381
# Finished in 0:00:01.680504
# Finished in 0:00:01.673523
# Finished in 0:00:01.709429
# Finished in 0:00:01.663550
# Finished in 0:00:01.691475
# Finished in 0:00:01.808143
# Finished in 0:00:01.957786
# Finished in 0:00:02.167182
# Finished in 0:00:02.264919
# Finished in 0:00:01.816163
# Finished in 0:00:01.833076
# Finished in 0:00:02.080438
# Finished in 0:00:03.800810
# Finished in 0:00:02.252566
# Finished in 0:00:01.754840
# Finished in 0:00:01.832654
# Finished in 0:00:01.880187
# Finished in 0:00:01.941167
# Finished in 0:00:01.864930
# Finished in 0:00:01.952800
# Finished in 0:00:01.938329
# Finished in 0:00:01.890325
# Finished in 0:00:01.811654
# Finished in 0:00:01.786812
# Finished in 0:00:01.740305
# Finished in 0:00:01.847057
# Finished in 0:00:01.755064
# Finished in 0:00:01.775921
# Finished in 0:00:01.773425
# Finished in 0:00:01.778415
# Finished in 0:00:01.775172
# Finished in 0:00:01.763360
# Finished in 0:00:01.741997
#  75%|███████▌  | 3/4 [04:07<01:23, 83.03s/it]Finished in 0:00:01.774324
# Finished in 0:00:01.781249
# Finished in 0:00:01.758051
# Finished in 0:00:01.818187
# Finished in 0:00:01.762827
# Finished in 0:00:01.756878
# Finished in 0:00:01.827922
# Finished in 0:00:01.740866
# Finished in 0:00:01.840135
# Finished in 0:00:01.759197
# Finished in 0:00:01.785782
# Finished in 0:00:01.750349
# Finished in 0:00:01.760799
# Finished in 0:00:01.794027
# Finished in 0:00:01.777403
# Finished in 0:00:01.771105
# Finished in 0:00:01.778409
# Finished in 0:00:01.803241
# Finished in 0:00:01.774156
# Finished in 0:00:01.781345
# Finished in 0:00:02.138951
# Finished in 0:00:03.080757
# Finished in 0:00:03.048846
# Finished in 0:00:02.729291
# Finished in 0:00:02.077252
# Finished in 0:00:01.823149
# Finished in 0:00:01.836816
# Finished in 0:00:01.784685
# Finished in 0:00:01.839094
# Finished in 0:00:01.756096
# Finished in 0:00:01.790790
# Finished in 0:00:01.867657
# Finished in 0:00:01.802372
# Finished in 0:00:01.795776
# Finished in 0:00:01.890474
# Finished in 0:00:01.841362
# Finished in 0:00:01.786775
# Finished in 0:00:01.778747
# Finished in 0:00:01.745579
# Finished in 0:00:01.818334
# Finished in 0:00:01.752906
# Finished in 0:00:01.747052
# Finished in 0:00:01.813940
# Finished in 0:00:01.783960
# Finished in 0:00:01.781674
# 100%|██████████| 4/4 [05:33<00:00, 83.38s/it]Finished in 0:00:01.802849
#
#
#  Best parameters and their resulting classification accuracy:
# [('lr:0.1, C:0.001, batch:50', 1.0),
#  ('lr:0.1, C:0.001, batch:100', 1.0),
#  ('lr:0.1, C:0.001, batch:200', 1.0),
#  ('lr:0.1, C:0.01, batch:50', 1.0),
#  ('lr:0.1, C:0.01, batch:100', 1.0)]

# %% [markdown]
# ## Classification accuracy and convergence plot

# %%
from DataLoader import *
from LinearSVM import *

dataloader = DataLoader()
xtrain, xtest, ytrain, ytest = dataloader.get_toydata_large()

# best hyperparameters
lr = 0.1; C = 0.001; batch_size=50
svm = LinearSVM(learning_rate=lr, regularization=C, batch_size=batch_size, epoch_count=3, collect_data=True)
svm.fit(xtrain, ytrain)

# Convergence Plots
plt.subplot(1,2,1)
plt.title("Hinge Loss", fontweight="bold", fontsize=11)
plt.plot(svm.losses, lw=3, alpha=0.6)
plt.xlabel("Epoch", fontweight="bold"); plt.ylabel("Loss", fontweight="bold")

plt.subplot(1,2,2)
plt.title("Classification Accuracy", fontweight="bold", fontsize=11)
plt.plot(svm.accuracies * 100, lw=3, alpha=0.6)
plt.xlabel("Epoch", fontweight="bold"); plt.ylabel("Accuracy %", fontweight="bold")
plt.tight_layout()
plt.show()

# classification accuracy
print("\nClassification accuracy evaluated on test set with computed weights:", end=" ")
print(round(svm.accuracy(xtest, ytest, svm.optimizer.weight), 2)*100, "%\n")
# Out:
# Finished in 0:00:02.356244
# Classification accuracy evaluated on test set with computed weights: 100.0 %

# %% [markdown]
# ## Hyperparameter Search -- MNIST

# %%
from MultiClassSVM import *
import matplotlib.pyplot as plt 
from DataLoader import *
from pprint import pprint 

dataloader = DataLoader()
xtrain, xtest, ytrain, ytest = dataloader.get_mnist()

# split 10.000 samples off xtrain and do hyperparameter-search using this validation set
indices = np.random.permutation(len(ytrain))
xtrain = xtrain[indices]
ytrain = ytrain[indices]

x_val = xtrain[:10**4]; y_val = ytrain[:10**4]
xtrain = xtrain[10**4:]; ytrain = ytrain[10**4:]

lrs = [0.01, 0.1, 0.5, 1]; Cs = [0.001, 0.01, 0.1]
batch_sizes = [50, 100, 200]

results = {}
for lr in tqdm(lrs):
    for C in Cs:
        for batch in batch_sizes:
            mc_svm = MultiClassSVM(lr=lr, C=C, batch_size=batch, max_iters=1)
            mc_svm.fit(xtrain, ytrain)
            results[f'lr:{lr}, C:{C}, batch:{batch}'] = mc_svm.accuracy(x_val, y_val)
results = sorted(results.items(), key=lambda l:l[1], reverse=True)

print("\n\n Best parameters and their resulting classification accuracy:")
pprint(results[:5])
# Out:
# 100%|██████████| 4/4 [29:08<00:00, 437.12s/it]
#
#  Best parameters and their resulting classification accuracy:
# [('lr:0.01, C:0.01, batch:50', 0.9163),
#  ('lr:0.1, C:0.001, batch:200', 0.9153),
#  ('lr:0.01, C:0.001, batch:50', 0.9148),
#  ('lr:0.01, C:0.1, batch:50', 0.9137),
#  ('lr:0.1, C:0.1, batch:200', 0.9128)]

# %% [markdown]
# ## Classification accuracy and convergence plot

# %%
from MultiClassSVM import *
import matplotlib.pyplot as plt 
from DataLoader import *
import seaborn as sns
sns.set_style('darkgrid')
sns.set(color_codes=True)
sns.set_context('paper')

dataloader = DataLoader()
xtrain, xtest, ytrain, ytest = dataloader.get_mnist()

# best hyperparameters
lr = 0.01; C = 0.01; batch_size=50
mc_svm = MultiClassSVM(lr=lr, C=C, batch_size=batch_size, max_iters=3, tqdm_toggle=True)
mc_svm.fit(xtrain, ytrain)
print(f"Runtime: {round(mc_svm.runtime, 2)} s")

# Convergence Plots
plt.subplot(1,2,1)
plt.title("MC-Hinge Loss", fontweight="bold", fontsize=11)
plt.plot(mc_svm.losses, lw=3, alpha=0.6)
plt.xlabel("Epoch", fontweight="bold"); plt.ylabel("Loss", fontweight="bold")

plt.subplot(1,2,2)
plt.title("Classification Accuracy", fontweight="bold", fontsize=11)
plt.plot(mc_svm.accuracies * 100, lw=2, alpha=0.8)
plt.xlabel("Epoch", fontweight="bold"); plt.ylabel("Accuracy %", fontweight="bold")

plt.tight_layout()
plt.show()

# classification accuracy
print("\nClassification accuracy evaluated on test set:", end=" ")
print(round(mc_svm.accuracy(xtest, ytest), 5)*100, "%")
# Out:
# 100%|██████████| 3/3 [03:08<00:00, 62.93s/it]
# Runtime: 188.8 s
# Classification accuracy evaluated on test set: 92.54 %
